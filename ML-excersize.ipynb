# %%
import pandas as pd
import numpy as np
songs = pd.read_csv('ml-03-data-processing-songs-dataset.csv')
songs.info()
songs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1991 non-null   object
#  2   Artist                  1986 non-null   object
#  3   Top Genre               1986 non-null   object
#  4   Year                    1987 non-null   float64
#  5   Month                   1994 non-null   object
#  6   Beats Per Minute (BPM)  1985 non-null   float64
#  7   Energy                  1986 non-null   float64
#  8   Danceability            970 non-null    float64
#  9   Loudness (dB)           1987 non-null   float64
#  10  Liveness                1986 non-null   float64
#  11  Valence                 960 non-null    float64
#  12  Length (Duration)       1985 non-null   object
#  13  Acousticness            1986 non-null   float64
# ...

# %%
# songs['Year'] = songs['Year'].replace(92.0, 1992.0)
#songs['Year'] = songs['Year'].map({'92': '1992'})
#print(songs['Year'].head())
# songs['Year'] = songs['Year'].astype(np.float64)
# print(songs['Year'].head())
songs['Month'] = songs['Month'].replace('Jan', '1')

songs['Month'] = songs['Month'].map(lambda m: )



print(songs.info())
songs['Month'] = songs['Month'].astype(np.float64)
print(songs['Month'].head())
# songs['Length (Duration)'] = songs['Length (Duration)'].map({',': ''})
# print(songs['Length (Duration)'].head())
# songs['Length (Duration)'] = songs['Length (Duration)'].astype(np.float64)
# print(songs['Length (Duration)'].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1991 non-null   object
#  2   Artist                  1986 non-null   object
#  3   Top Genre               1986 non-null   object
#  4   Year                    1987 non-null   float64
#  5   Month                   1994 non-null   object
#  6   Beats Per Minute (BPM)  1985 non-null   float64
#  7   Energy                  1986 non-null   float64
#  8   Danceability            970 non-null    float64
#  9   Loudness (dB)           1987 non-null   float64
#  10  Liveness                1986 non-null   float64
#  11  Valence                 960 non-null    float64
#  12  Length (Duration)       1985 non-null   object
#  13  Acousticness            1986 non-null   float64
# ...

# %%
songs.info()
# songs.isna().sum()
# for i in songs:
#     if (songs[i]).value_counts().NaN > (len(songs[i])/2):
#         songs.drop([i])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1991 non-null   object
#  2   Artist                  1986 non-null   object
#  3   Top Genre               1986 non-null   object
#  4   Year                    1987 non-null   float64
#  5   Month                   1 non-null      float64
#  6   Beats Per Minute (BPM)  1985 non-null   float64
#  7   Energy                  1986 non-null   float64
#  8   Danceability            970 non-null    float64
#  9   Loudness (dB)           1987 non-null   float64
#  10  Liveness                1986 non-null   float64
#  11  Valence                 960 non-null    float64
#  12  Length (Duration)       0 non-null      float64
#  13  Acousticness            1986 non-null   float64
# ...

# %%
for i in songs['Index']:
# Out:
#   Input In [45]
#
#     ^
# IndentationError: expected an indented block
